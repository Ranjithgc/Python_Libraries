# %% [markdown]
# ***@Author: Ranjith G C***
# <br>
# ***@Date: 2021-07-15***
# <br>
# ***@Last Modified by: Ranjith G C***
# <br>
# ***@Last Modified time: 2021-07-15***
# <br>
# ***@Title : Program Aim to draw a scatter plot of day against total bill for tips.csv file.***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_style('whitegrid')
# Import Data
df = sns.load_dataset('tips')

# Construct plot
sns.scatterplot(x = "day", y = "total_bill", data = df)
plt.show()
