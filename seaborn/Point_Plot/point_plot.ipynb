# %% [markdown]
# ***@Author: Ranjith G C***
# <br>
# ***@Date: 2021-07-15***
# <br>
# ***@Last Modified by: Ranjith G C***
# <br>@
# ***Last Modified time: 2021-07-15***
# <br>
# ***@Title : Program Aim to draw a point plot of sex against survived from a csv file***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_style('darkgrid')
# Import Data
df = sns.load_dataset('titanic')

# Construct plot
sns.pointplot(x = "sex", y = "survived", data = df)
plt.show()
