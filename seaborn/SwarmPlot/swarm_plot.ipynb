# %% [markdown]
# ***@Author: Ranjith G C***
# <br>
# ***@Date: 2021-07-15***
# <br>
# ***@Last Modified by: Ranjith G C***
# <br>
# ***@Last Modified time: 2021-07-15***
# <br>
# ***@Title : Program Aim to draw a swarmplot of total bill against size for a given dataset.***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_style('whitegrid')
# Import Data
df = sns.load_dataset('tips')

# Construct plot
sns.swarmplot(x="total_bill", y="size", data=df)
plt.show()
# Out:
# /home/ubunta/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/ubunta/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ***2. swarmplot of total_bill against size for a given dataset.***

# %%
sns.swarmplot(x="total_bill", y="day", data=df)
plt.show()
