# %% [markdown]
# ***@Author: Ranjith G C***
# <br>
# ***@Date: 2021-07-15***
# <br>
# ***@Last Modified by: Ranjith G C***
# <br>
# ***@Last Modified time: 2021-07-15***
# <br>
# ***@Title : Program Aim to draw a scatterplot for random 500 for x and y coordinates.and style it.***

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from pylab import randn

x = randn(500)
y = randn(500)
df = pd.DataFrame({
    'col_x':x, 'col_y':y
})
df.head()

fig = px.scatter(df, x='col_x', y='col_y',
                 width=700, height=500,
                 title="2D Scatter Plot")
fig.show()
