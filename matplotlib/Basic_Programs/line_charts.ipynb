# %% [markdown]
# ***@Author: Ranjith G C***
# <br>
# ***@Date: 2021-07-13***
# <br>
# ***@Last Modified by: Ranjith G C***
# <br>
# ***@Last Modified time: 2021-07-13***
# <br>
# ***@Title : Program Aim to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.***

# %%
import matplotlib.pyplot as plt
import pandas as pd

try:
    df = pd.read_csv('fdata.csv', sep=',', parse_dates=True, index_col=0)
    df.plot()
    plt.show()
except Exception as e:
    logger.error(e)
