# %% [markdown]
# ***@Author: Ranjith G C***
# <br>
# ***@Date: 2021-07-13***
# <br>
# ***@Last Modified by: Ranjith G C***
# <br>
# ***@Last Modified time: 2021-07-13***
# <br>
# ***@Title : Program Aim to display the current axis limits values and set new axis values. ***
# <br>

# %%
import matplotlib.pyplot as plt
from loggers import logger

try:
    X = range(1, 50)
    Y = [value * 3 for value in X]
    plt.plot(X, Y)
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title('Draw a line.')

    # shows the current axis limits values
    print(plt.axis()) 
    # set new axes limits
    # Limit of x axis 0 to 100
    # Limit of y axis 0 to 200
    plt.axis([0, 100, 0, 200]) 
    # Display the figure.
    plt.show()
except Exception as e:
    logger.error(e)
# Out:
# (-1.4000000000000004, 51.4, -4.2, 154.2)
